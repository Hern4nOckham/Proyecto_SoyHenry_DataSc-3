# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# Libreria
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### **Nubes de palabras**

# %%
# Creacion dataframe
yelp=pd.read_csv("ETL_YELP_todos_estados.csv")

# %%
# Visualizacion primeras cinco columnas
yelp.head(5)
# Out:
#               Business_id             Name                        Categories  \
# 0  yS0TsUzKBQlHQCZZeBrxww  Tortas El Guero  Mexican, Sandwiches, Restaurants
# 1  yS0TsUzKBQlHQCZZeBrxww  Tortas El Guero  Mexican, Sandwiches, Restaurants
# 2  yS0TsUzKBQlHQCZZeBrxww  Tortas El Guero  Mexican, Sandwiches, Restaurants
# 3  yS0TsUzKBQlHQCZZeBrxww  Tortas El Guero  Mexican, Sandwiches, Restaurants
# 4  yS0TsUzKBQlHQCZZeBrxww  Tortas El Guero  Mexican, Sandwiches, Restaurants
#
#    Stars                                               Text  Useful  Funny  \
# 0    5.0  Hands down best Mexican in Indy! This place al...       0      0
# 1    5.0  After reading all the reviews & hearing great ...       1      0
# 2    4.0  First time here, had decent reviews so I wante...       2      0
# 3    4.0  Service was fast! Got the cabeza taco and it w...       1      0
# 4    5.0  Man, was I blown away!\n\nWas looking for a de...       2      0
#
# ...

# %% [markdown]
# Vemos que en la columna "Text" estan las reseñas que dejan los clientes cuando van a un restaurant Mexicano.

# %%
# Extraemos del dataframe la columna "Text"
text = yelp["Text"]

# %%
# Creamos la nube de palabras
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = None,
                min_font_size = 10).generate(' '.join(text))

# %%
# Mostramos la nube de palabras
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# Las palabras que mas se repiten en las reseñas de los clientes son:
#
# - Place     >>> Lugar
# - Food      >>> Alimento
# - Good      >>> Bien
# - Order     >>> Orden
# - Taco      >>> Taco (Plato mexicano)
# - Deliciou  >>> Delicioso
# - Service   >>> Servicio
# - One       >>> Uno
# - Ordered   >>> Ordenado
# - Love      >>> Amor
